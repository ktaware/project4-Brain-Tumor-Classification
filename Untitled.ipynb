# %%
from PIL import Image
import glob
import pandas as pd
image_list_glioma_tumor = []
for filename in glob.glob('D:\project4\Testing\glioma_tumor/*.jpg'): #assuming gif
    im=Image.open(filename)
    image_list_glioma_tumor.append(im)

# %%
image_list_glioma_tumor
df = pd.DataFrame(image_list_glioma_tumor)
df
# Out:
#                                                     0
# 0   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 1   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 2   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 3   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 4   <PIL.JpegImagePlugin.JpegImageFile image mode=...
# ..                                                ...
# 95  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 96  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 97  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 98  <PIL.JpegImagePlugin.JpegImageFile image mode=...
# 99  <PIL.JpegImagePlugin.JpegImageFile image mode=...
#
# [100 rows x 1 columns]

# %%
image_list_meningioma_tumor = []
for filename in glob.glob('D:\project4\Testing\meningioma_tumor/*.jpg'): #assuming gif
    im=Image.open(filename)
    image_list_meningioma_tumor.append(im)

# %%
image_list_meningioma_tumor
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=440x278>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=257x307>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=228x221>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=212x237>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=528x581>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=295x394>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=219x234>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=262x308>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=206x249>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=530x526>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=455x500>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x223>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=472x546>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=441x427>,
# ...

# %%
image_list_no_tumor = []
for filename1 in glob.glob('D:\project4\Testing\no_tumor/*.jpg'): #assuming gif
    im=Image.open(filename1)
    image_list_no_tumor.append(im)

# %%
image_list_no_tumor
# Out:
# []

# %%
image_list_pituitary_tumor = []
for filename in glob.glob('D:\project4\Testing\pituitary_tumor/*.jpg'): #assuming gif
    im=Image.open(filename)
    image_list_pituitary_tumor.append(im)

# %%
 image_list_pituitary_tumor
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=685x681>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=202x202>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1280>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=436x429>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=502x502>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=502x502>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=502x502>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x378>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x378>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1358x1322>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1358x1322>,
# ...
